# %% [markdown]
# # Laboratórios de Bioinformática
# ### Análise de homologias por BLAST
#
# **Grupo 6**: Joana Gabriel, Maria Couto, Teresa Coimbra

# %% [markdown]
# ### Procura de genes Homólogos
#
# A similaridade entre sequências pode ser verificada através de algoritmos como o BLAST. O BLAST(Basic Local Alignment Search Tool) possibilita  uma comparação da informação de sequências biológicas (seja de nucleótidos ou de aminoácidos) fornecidas na pesquisa, com sequências contidas numa base de dados. Os resultados desta comparação são filtrados de acordo com o grau de semelhança existente entre as sequências.
#
# Através do BioPython é possível executar o BLAST com os parâmetros desejados e analisar os resultados. A função utilizada foi a função qblast() que está contida no módulo Bio.Blast.NCBIWWW.
# Esta função recebe três parâmetros não opcionais, que incluem o programa a utilizar, a base de dados e a sequência a pesquisar (query).
#
# O programa a utilizar pode ser uma das opções seguintes de pesquisa:
# - nucleótidos (blastn),
# - proteínas (blastp),
# - pesquisa contra sequências existentes na base de dados do NCBI (blastx),
# - pesquisa por sequências de nucleótidos traduzidas utilizando uma sequência de uma proteína (tblastn),
# - pesquisa por sequências de nucleótidos traduzidas utilizando uma sequência de nucleótidos traduzida (tblastx).
#
#
# Quanto à base de dados sobre a qual é efetuada a pesquisa existem diversas possibilidades, tais como: nt, nr, refseq_rna, est , swissprot, SRA, TSA, refseq_genomes, entre outras.
# A sequência a pesquisar ou query pode ser fornecida como uma string (a própria sequência), em formato FASTA ou com um identificador.
#
# De acordo com a pesquisa, são identificadas proteínas ou genes homólogos, que demonstram uma similaridade estatisticamente significativa (pois esta reflete uma ancestralidade em comum).
#
# Foram efetuados BLAST para os ficheiros FASTA gerados na pesquisa realizada anteriormente, utilizando a opção blastp. Já a base de dados selecionada foi a Swissprot. Os ficheiros gerados têm o formato xml.

# %%
def blast(filename,search_program = 'blastp', database = 'swissprot'):
    '''
    Esta função permite-nos invocar o blast utilizando a função qblast() do Biopython. 
    Recebe:
        -nome do ficheiro .faa (str);
        -programa do blast utilizado para fazer a pesquisa (str);
        -nome da base de dados sobre a qual é efetuada a pesquisa (str).
    Retorna:
        os ficheiros xml correspondentes com o resultado do Blast'''
    
    from Bio.Blast import NCBIWWW
    from Bio import SeqIO
    
    record        = SeqIO.read(open(filename+'.faa'), format = 'fasta')
    result_handle = NCBIWWW.qblast('blastp','swissprot',record.format('fasta')) # escolhemos a swissprot por ser uma base de dados curada
    save_file     = open(filename+'.xml','w') 
    save_file.write(result_handle.read())
    save_file.close()
    result_handle.close()

# %% [markdown]
# ### Correr o Blast de modo interativo:

# %%
def run_blast():
    fn        = input('Inserir o nome do ficheiro com a sequência para correr o blast: ')
    decide    = int(input('O programa de pesquisa utilizado é o blastp e a base de dados a Swissprot. Deseja alterar estes parâmetros? 0 - Não, manter; 1 - Sim.'))
    if decide == 0:
        blast(fn)
    else:
        opt_prog = input('Escolher um programa do blast para efetuar a pesquisa: blastn, blastp, blastx, tblast, tblastx: ')
        assert opt_prog in ['blastn','blastp','blastx','tblast','tblastx'], 'O programa não consta na lista de possibilidades do blast.'
        opt_db   = input('Escolher uma base de dados sobre a qual será efetuada a pesquisa. Exemplos: nt,nr,refseq_rna,est,swissprot,SRA,TSA,refseq_genomes. Para mais opções verificar ftp://ftp.ncbi.nlm.nih.gov/pub/factsheets/HowTo_BLASTGuide.pdf. Base de dados escolhida: ')
        blast(fn,opt_prog,opt_db)

# %%
#run_blast()

# %% [markdown]
# ### Correr o Blast dos ficheiros obtidos na pesquisa feita anteriormente:

# %%
#blast('spP0DTC9.1NCAP_SARS2')     # N protein
#blast('NP_001011724.1')           # heterogeneous nuclear ribonucleoprotein
#blast('NP_001011725.1')           # heterogeneous nuclear ribonucleoprotein
#blast('NP_002127.1')              # heterogeneous nuclear ribonucleoprotein
#blast('NP_112420.1')              # heterogeneous nuclear ribonucleoprotein
#blast('NP_001138574.1')           # SMAD3       
#blast('NP_001138575.1')           # SMAD3
#blast('NP_001138576.1')           # SMAD3
#blast('NP_005893.1')              # SMAD3

# %% [markdown]
# ### Número de alinhamentos em cada ficheiro xml resultante:
#
# Cada sequência gera um determinado número de alinhamentos associado.

# %%
def n_align(filename):
    '''Recebe o nome de um ficheiro xml(str)
    Retorna o número de alinhamentos existentes no ficheiro (int)'''
    from Bio.Blast import NCBIXML
    result_handle = open('./'+filename+'.xml') 
    blast_records = NCBIXML.read(result_handle)
    c = 0 
    for alignment in blast_records.alignments:
        c+=1
    print('O número de alinhamentos para o ficheiro',filename,'é:', c)

# %%
filenames = ['spP0DTC9.1NCAP_SARS2','NP_001011724.1','NP_001011725.1','NP_001138574.1','NP_001138575.1','NP_001138576.1','NP_005893.1','NP_002127.1','NP_112420.1']
for fname in filenames:
    n_align(fname)
# Out:
# O número de alinhamentos para o ficheiro spP0DTC9.1NCAP_SARS2 é: 50
# O número de alinhamentos para o ficheiro NP_001011724.1 é: 50
# O número de alinhamentos para o ficheiro NP_001011725.1 é: 50
# O número de alinhamentos para o ficheiro NP_001138574.1 é: 38
# O número de alinhamentos para o ficheiro NP_001138575.1 é: 38
# O número de alinhamentos para o ficheiro NP_001138576.1 é: 41
# O número de alinhamentos para o ficheiro NP_005893.1 é: 40
# O número de alinhamentos para o ficheiro NP_002127.1 é: 50
# O número de alinhamentos para o ficheiro NP_112420.1 é: 50

# %% [markdown]
# # Automatização da decisão de existência de homologias significativas

# %% [markdown]
# ### Análise dos resultados obtidos
#
#
# Podemos inferir que existe homologia entre as sequências de acordo com o seu grau de semelhança. É possível que existam sequências homólogas que não partilhem um elevado grau de semelhança, principalmente quando se comparam sequências de DNA, contudo, neste caso, tendo em conta que é feita uma comparação entre sequências de aminoácidos, considera-se que este risco é menor.
#
# A semelhança pode ser avaliada de acordo com diferentes parâmetros tais como o E-value, a percentagem de identidade e os bit-scores.
#
# Para avaliar  a homologia entre sequências os parâmetros mais relevantes são o **E-value** e os **bit-scores**.
#
# O valor do E-value depende da extensão do alinhamento e do número de sequências que existem na base de dados. Quanto menor o E-value, mais significativo o alinhamento, pois este valor traduz o número esperado de vezes que um alinhamento pode ocorrer devido ao acaso, tendo em conta os aloritmos existentes.
#
# A significância do bit-score depende do tamanho da base de dados e da sequência query. De uma forma geral, é possível considerar um resultado como estatisticamente significativo se o bit-score for de 40-50.
#
# Os HSP(High-scoring Segment Pair) correspondem aos melhores alinhamentos locais obtido (sem espaçamentos).
#
# Consideramos homologias significativas as que têm um score alto (>200).

# %%
def blast_result(filename, E_VALUE_THRES=0.0001, bit_score = 50, SCORE=200):
    from Bio.Blast import NCBIXML
    from Bio import SeqIO
    result_handle = open('./'+filename+'.xml') 
    blast_records = NCBIXML.read(result_handle)
    
    List1 = []
    for alignment in blast_records.alignments:
        for hsp in alignment.hsps:
            l = []
            if (hsp.expect < E_VALUE_THRES) and (hsp.bits > bit_score) and (hsp.score > SCORE):
                print('****Alignment****')
                print('sequence:', alignment.title)
                print('e.value:',hsp.expect)
                print('bit-score:',hsp.bits)
                print('hsp score:', hsp.score)
                #print ( hsp.query [0:75] + '...')             # query
                #print( hsp.match [0:75] + '...')              # alinhamento
                #print(hsp.sbjct [0:75] + '...')               # seq que alinhou
                
                l.append(hsp)
                
                #l.append(alignment.title)
                #l.append(hsp.expect)
                #l.append(hsp.bits)
                #l.append(hsp.score)
                List1.append(l)
        
    return List1

# %%
def blast_result(filename, E_VALUE_THRES=0.0001, bit_score = 50, SCORE=200):
    from Bio.Blast import NCBIXML
    from Bio import SeqIO
    result_handle = open('./'+filename+'.xml') 
    blast_records = NCBIXML.read(result_handle)
    
    for alignment in blast_records.alignments:
        for hsp in alignment.hsps:
       
            if (hsp.expect < E_VALUE_THRES) and (hsp.bits > bit_score) and (hsp.score > SCORE):
                print('****Alignment****')
                print('sequence:', alignment.title)
                print('e.value:',hsp.expect)
                print('bit-score:',hsp.bits)
                print('hsp score:', hsp.score)
    
    return List1

# %%
blast_result('NP_001011725.1')
# Out:
# ****Alignment****
# sequence: sp|Q32P51.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1-like 2; Short=hnRNP A1-like 2; AltName: Full=hnRNP core protein A1-like 2 [Homo sapiens]
# e.value: 0.0
# bit-score: 642.114
# hsp score: 1655.0
# ****Alignment****
# sequence: sp|A5A6H4.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand-binding protein; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Pan troglodytes] >sp|P09867.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand RNA-binding protein; AltName: Full=Unwinding protein 1; Short=UP1; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Bos taurus] >sp|P49312.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=HDP-1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand-binding protein; AltName: Full=Topoisomerase-inhibitor suppressed; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Mus musculus]
# e.value: 0.0
# bit-score: 615.92
# hsp score: 1587.0
# ****Alignment****
# sequence: sp|P04256.3| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; Short=HDP; AltName: Full=Single-strand RNA-binding protein; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Rattus norvegicus]
# e.value: 0.0
# bit-score: 613.994
# hsp score: 1582.0
# ****Alignment****
# sequence: sp|Q28521.3| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand-binding protein; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Macaca mulatta]
# e.value: 1.43759e-169
# bit-score: 476.478
# hsp score: 1225.0
# ****Alignment****
# sequence: sp|P09651.5| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand RNA-binding protein; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Homo sapiens]
# e.value: 5.99324e-133
# bit-score: 385.571
# hsp score: 989.0
# ****Alignment****
# sequence: sp|P17130.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A1 homolog; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand-binding protein; AltName: Full=hnRNP core protein A1 [Xenopus laevis]
# e.value: 4.2141e-126
# bit-score: 367.851
# hsp score: 943.0
# ****Alignment****
# sequence: sp|P51992.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3 homolog 2; AltName: Full=hnRNP A3(B) [Xenopus laevis]
# e.value: 2.61095e-116
# bit-score: 343.969
# hsp score: 881.0
# ****Alignment****
# sequence: sp|P51991.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3; Short=hnRNP A3 [Homo sapiens]
# e.value: 3.34243e-115
# bit-score: 340.887
# hsp score: 873.0
# ****Alignment****
# sequence: sp|Q6URK4.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3; Short=hnRNP A3 [Rattus norvegicus] >sp|Q8BG05.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3; Short=hnRNP A3 [Mus musculus]
# e.value: 3.45345e-115
# bit-score: 340.887
# hsp score: 873.0
# ****Alignment****
# sequence: sp|P51989.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A2 homolog 1; AltName: Full=hnRNP A2(A) [Xenopus laevis]
# e.value: 3.13235e-107
# bit-score: 319.316
# hsp score: 817.0
# ****Alignment****
# sequence: sp|Q2HJ60.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Bos taurus]
# e.value: 7.13602e-106
# bit-score: 315.464
# hsp score: 807.0
# ****Alignment****
# sequence: sp|O88569.2| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Mus musculus]
# e.value: 1.76045e-105
# bit-score: 315.079
# hsp score: 806.0
# ****Alignment****
# sequence: sp|P22626.2| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Homo sapiens]
# e.value: 1.76045e-105
# bit-score: 315.079
# hsp score: 806.0
# ****Alignment****
# sequence: sp|A7VJC2.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Rattus norvegicus]
# e.value: 1.09639e-104
# bit-score: 313.153
# hsp score: 801.0
# ****Alignment****
# sequence: sp|Q5RBU8.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Pongo abelii]
# e.value: 1.18321e-104
# bit-score: 313.153
# hsp score: 801.0
# ****Alignment****
# sequence: sp|Q9TTV2.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1; AltName: Full=Vitamin D response element-binding protein 2; Short=VDRE-BP 2 [Saguinus oedipus]
# e.value: 1.59045e-104
# bit-score: 312.383
# hsp score: 799.0
# ****Alignment****
# sequence: sp|P51990.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A2 homolog 2; AltName: Full=hnRNP A2(B) [Xenopus laevis]
# e.value: 2.33073e-103
# bit-score: 309.686
# hsp score: 792.0
# ****Alignment****
# sequence: sp|P21522.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, A2/B1 homolog [Schistocerca americana]
# e.value: 8.8629e-75
# bit-score: 236.113
# hsp score: 601.0
# ****Alignment****
# sequence: sp|P07909.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=PEN repeat clone P9; AltName: Full=hnRNP core protein A1-A [Drosophila melanogaster]
# e.value: 1.07735e-73
# bit-score: 234.187
# hsp score: 596.0
# ****Alignment****
# sequence: sp|Q13151.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A0; Short=hnRNP A0 [Homo sapiens]
# e.value: 1.97083e-71
# bit-score: 226.483
# hsp score: 576.0
# ****Alignment****
# sequence: sp|Q9CX86.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A0; Short=hnRNP A0 [Mus musculus]
# e.value: 2.81647e-71
# bit-score: 226.098
# hsp score: 575.0
# ****Alignment****
# sequence: sp|P48810.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein 87F; AltName: Full=HRP36.1 protein; AltName: Full=Protein P11 [Drosophila melanogaster]
# e.value: 1.3603e-70
# bit-score: 226.868
# hsp score: 577.0
# ****Alignment****
# sequence: sp|Q22037.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1 [Caenorhabditis elegans]
# e.value: 3.01916e-67
# bit-score: 217.238
# hsp score: 552.0
# ****Alignment****
# sequence: sp|Q02926.1| RecName: Full=Ribonucleoprotein RB97D [Drosophila melanogaster]
# e.value: 2.40638e-55
# bit-score: 189.889
# hsp score: 481.0
# ****Alignment****
# sequence: sp|O43347.1| RecName: Full=RNA-binding protein Musashi homolog 1; Short=Musashi-1 [Homo sapiens]
# e.value: 2.99807e-47
# bit-score: 165.622
# hsp score: 418.0
# ****Alignment****
# sequence: sp|Q61474.1| RecName: Full=RNA-binding protein Musashi homolog 1; Short=Musashi-1 [Mus musculus]
# e.value: 5.09208e-47
# bit-score: 165.236
# hsp score: 417.0
# ****Alignment****
# sequence: sp|Q8K3P4.1| RecName: Full=RNA-binding protein Musashi homolog 1; Short=Musashi-1 [Rattus norvegicus]
# e.value: 5.48401e-47
# bit-score: 165.236
# hsp score: 417.0
# ****Alignment****
# sequence: sp|Q99020.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A/B; Short=hnRNP A/B; AltName: Full=CArG-binding factor-A; Short=CBF-A [Mus musculus]
# e.value: 1.05633e-46
# bit-score: 162.155
# hsp score: 409.0
# ****Alignment****
# sequence: sp|Q920Q6.1| RecName: Full=RNA-binding protein Musashi homolog 2; Short=Musashi-2 [Mus musculus]
# e.value: 1.08314e-46
# bit-score: 163.696
# hsp score: 413.0
# ****Alignment****
# sequence: sp|Q96DH6.1| RecName: Full=RNA-binding protein Musashi homolog 2; Short=Musashi-2 [Homo sapiens]
# e.value: 1.33397e-46
# bit-score: 163.31
# hsp score: 412.0
# ****Alignment****
# sequence: sp|O94432.1| RecName: Full=Uncharacterized RNA-binding protein C660.15 [Schizosaccharomyces pombe 972h-]
# e.value: 2.60664e-45
# bit-score: 163.31
# hsp score: 412.0
# ****Alignment****
# sequence: sp|Q9JJ54.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein D0; Short=hnRNP D0; AltName: Full=AU-rich element RNA-binding protein 1 [Rattus norvegicus]
# e.value: 1.08039e-44
# bit-score: 158.688
# hsp score: 400.0
# ****Alignment****
# sequence: sp|Q14103.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D0; Short=hnRNP D0; AltName: Full=AU-rich element RNA-binding protein 1 [Homo sapiens]
# e.value: 1.27091e-44
# bit-score: 158.688
# hsp score: 400.0
# ****Alignment****
# sequence: sp|Q60668.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein D0; Short=hnRNP D0; AltName: Full=AU-rich element RNA-binding protein 1 [Mus musculus]
# e.value: 1.57006e-44
# bit-score: 158.303
# hsp score: 399.0
# ****Alignment****
# sequence: sp|Q9VVE5.3| RecName: Full=RNA-binding protein Musashi homolog Rbp6 [Drosophila melanogaster]
# e.value: 9.94133e-44
# bit-score: 156.762
# hsp score: 395.0
# ****Alignment****
# sequence: sp|Q3SWU3.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL [Rattus norvegicus]
# e.value: 9.89821e-43
# bit-score: 152.91
# hsp score: 385.0
# ****Alignment****
# sequence: sp|Q640A2.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL [Xenopus tropicalis]
# e.value: 7.43863e-42
# bit-score: 149.828
# hsp score: 377.0
# ****Alignment****
# sequence: sp|Q5ZI72.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL [Gallus gallus]
# e.value: 7.7075e-42
# bit-score: 149.828
# hsp score: 377.0
# ****Alignment****
# sequence: sp|Q9Z130.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL; AltName: Full=JKT41-binding protein [Mus musculus]
# e.value: 1.01525e-41
# bit-score: 149.443
# hsp score: 376.0
# ****Alignment****
# sequence: sp|Q8W034.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein 1; Short=hnRNP1 [Arabidopsis thaliana]
# e.value: 4.46713e-41
# bit-score: 150.599
# hsp score: 379.0
# ****Alignment****
# sequence: sp|O14979.3| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL; AltName: Full=AU-rich element RNA-binding factor; AltName: Full=JKT41-binding protein; AltName: Full=Protein laAUF1 [Homo sapiens]
# e.value: 8.28198e-41
# bit-score: 150.214
# hsp score: 378.0
# ****Alignment****
# sequence: sp|Q99383.1| RecName: Full=Nuclear polyadenylated RNA-binding protein 4; AltName: Full=Cleavage factor IB; Short=CFIB [Saccharomyces cerevisiae S288C]
# e.value: 5.41206e-40
# bit-score: 150.214
# hsp score: 378.0
# ****Alignment****
# sequence: sp|Q96EP5.1| RecName: Full=DAZ-associated protein 1; AltName: Full=Deleted in azoospermia-associated protein 1 [Homo sapiens]
# e.value: 6.83191e-40
# bit-score: 147.517
# hsp score: 371.0
# ****Alignment****
# sequence: sp|Q6NU14.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like-B; Short=hnRNP D-like B; Short=hnRNP DL-B [Xenopus laevis]
# e.value: 6.92508e-40
# bit-score: 144.436
# hsp score: 363.0
# ****Alignment****
# sequence: sp|Q7ZX83.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like-A; Short=hnRNP D-like A; Short=hnRNP DL-A [Xenopus laevis]
# e.value: 2.69908e-39
# bit-score: 142.895
# hsp score: 359.0
# ****Alignment****
# sequence: sp|Q9JII5.2| RecName: Full=DAZ-associated protein 1; AltName: Full=Deleted in azoospermia-associated protein 1 [Mus musculus]
# e.value: 5.42782e-39
# bit-score: 145.206
# hsp score: 365.0
# ****Alignment****
# sequence: sp|P48809.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein 27C; Short=Hrb27-C; AltName: Full=HRP48.1; AltName: Full=hnRNP 48 [Drosophila melanogaster]
# e.value: 5.49357e-39
# bit-score: 145.206
# hsp score: 365.0
# ****Alignment****
# sequence: sp|Q98SJ2.1| RecName: Full=DAZ-associated protein 1; AltName: Full=Deleted in azoospermia-associated protein 1; AltName: Full=Proline-rich Vg1 mRNA-binding protein [Xenopus laevis]
# e.value: 5.0565e-38
# bit-score: 141.354
# hsp score: 355.0
# ****Alignment****
# sequence: sp|Q99729.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A/B; Short=hnRNP A/B; AltName: Full=APOBEC1-binding protein 1; Short=ABBP-1 [Homo sapiens]
# e.value: 6.62466e-37
# bit-score: 137.887
# hsp score: 346.0
# ****Alignment****
# sequence: sp|Q08473.3| RecName: Full=RNA-binding protein squid; AltName: Full=Heterogeneous nuclear ribonucleoprotein 40; Short=HNRNP 40 [Drosophila melanogaster]
# e.value: 4.08138e-31
# bit-score: 122.479
# hsp score: 306.0
# [[<Bio.Blast.Record.HSP at 0x1c6caa40520>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40190>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40610>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa408e0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40eb0>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca9edbe0>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca9edd30>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca9edca0>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca9edd60>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca9edc10>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca9edc40>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8dee80>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8de160>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8debe0>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8defa0>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8dee20>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8de790>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8e7970>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8e7850>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa572e0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57b50>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57f10>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57eb0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57a90>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57be0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa579d0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57220>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57d90>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa271f0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa27f40>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa27700>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa27d30>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa279a0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa276a0>],
#  [<Bio.Blast.Record.HSP at 0x1c6c92e6be0>],
#  [<Bio.Blast.Record.HSP at 0x1c6c92e6130>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b070>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b100>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b190>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b220>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b2e0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b370>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b340>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b4f0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b4c0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b670>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b700>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b790>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b820>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa9b8e0>]]

# %%
blast_result('NP_112420.1')
# Out:
# ****Alignment****
# sequence: sp|P09651.5| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand RNA-binding protein; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Homo sapiens]
# e.value: 0.0
# bit-score: 721.079
# hsp score: 1860.0
# ****Alignment****
# sequence: sp|A5A6H4.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand-binding protein; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Pan troglodytes] >sp|P09867.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand RNA-binding protein; AltName: Full=Unwinding protein 1; Short=UP1; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Bos taurus] >sp|P49312.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=HDP-1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand-binding protein; AltName: Full=Topoisomerase-inhibitor suppressed; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Mus musculus]
# e.value: 0.0
# bit-score: 592.808
# hsp score: 1527.0
# ****Alignment****
# sequence: sp|P04256.3| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; Short=HDP; AltName: Full=Single-strand RNA-binding protein; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Rattus norvegicus]
# e.value: 0.0
# bit-score: 590.882
# hsp score: 1522.0
# ****Alignment****
# sequence: sp|Q28521.3| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand-binding protein; AltName: Full=hnRNP core protein A1; Contains: RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, N-terminally processed [Macaca mulatta]
# e.value: 0.0
# bit-score: 587.415
# hsp score: 1513.0
# ****Alignment****
# sequence: sp|P17130.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A1 homolog; Short=hnRNP A1; AltName: Full=Helix-destabilizing protein; AltName: Full=Single-strand-binding protein; AltName: Full=hnRNP core protein A1 [Xenopus laevis]
# e.value: 7.16855e-132
# bit-score: 384.8
# hsp score: 987.0
# ****Alignment****
# sequence: sp|P51968.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3 homolog 1; AltName: Full=hnRNP A3(A) [Xenopus laevis]
# e.value: 5.47538e-122
# bit-score: 359.762
# hsp score: 922.0
# ****Alignment****
# sequence: sp|P51992.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3 homolog 2; AltName: Full=hnRNP A3(B) [Xenopus laevis]
# e.value: 1.30206e-121
# bit-score: 359.377
# hsp score: 921.0
# ****Alignment****
# sequence: sp|P51991.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3; Short=hnRNP A3 [Homo sapiens]
# e.value: 2.96999e-121
# bit-score: 358.221
# hsp score: 918.0
# ****Alignment****
# sequence: sp|Q6URK4.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3; Short=hnRNP A3 [Rattus norvegicus] >sp|Q8BG05.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A3; Short=hnRNP A3 [Mus musculus]
# e.value: 3.07006e-121
# bit-score: 358.221
# hsp score: 918.0
# ****Alignment****
# sequence: sp|P51989.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A2 homolog 1; AltName: Full=hnRNP A2(A) [Xenopus laevis]
# e.value: 2.26626e-110
# bit-score: 329.331
# hsp score: 843.0
# ****Alignment****
# sequence: sp|Q2HJ60.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Bos taurus]
# e.value: 8.3485e-110
# bit-score: 327.791
# hsp score: 839.0
# ****Alignment****
# sequence: sp|O88569.2| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Mus musculus]
# e.value: 1.49153e-109
# bit-score: 327.405
# hsp score: 838.0
# ****Alignment****
# sequence: sp|P22626.2| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Homo sapiens]
# e.value: 1.49153e-109
# bit-score: 327.405
# hsp score: 838.0
# ****Alignment****
# sequence: sp|A7VJC2.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Rattus norvegicus]
# e.value: 1.08004e-108
# bit-score: 325.479
# hsp score: 833.0
# ****Alignment****
# sequence: sp|Q5RBU8.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1 [Pongo abelii]
# e.value: 1.10379e-108
# bit-score: 325.094
# hsp score: 832.0
# ****Alignment****
# sequence: sp|Q9TTV2.1| RecName: Full=Heterogeneous nuclear ribonucleoproteins A2/B1; Short=hnRNP A2/B1; AltName: Full=Vitamin D response element-binding protein 2; Short=VDRE-BP 2 [Saguinus oedipus]
# e.value: 1.89634e-108
# bit-score: 324.324
# hsp score: 830.0
# ****Alignment****
# sequence: sp|P51990.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A2 homolog 2; AltName: Full=hnRNP A2(B) [Xenopus laevis]
# e.value: 7.81947e-108
# bit-score: 323.168
# hsp score: 827.0
# ****Alignment****
# sequence: sp|P48810.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein 87F; AltName: Full=HRP36.1 protein; AltName: Full=Protein P11 [Drosophila melanogaster]
# e.value: 1.79369e-75
# bit-score: 241.506
# hsp score: 615.0
# ****Alignment****
# sequence: sp|P21522.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1, A2/B1 homolog [Schistocerca americana]
# e.value: 2.68584e-75
# bit-score: 239.58
# hsp score: 610.0
# ****Alignment****
# sequence: sp|P07909.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1; AltName: Full=PEN repeat clone P9; AltName: Full=hnRNP core protein A1-A [Drosophila melanogaster]
# e.value: 1.98404e-70
# bit-score: 227.639
# hsp score: 579.0
# ****Alignment****
# sequence: sp|Q22037.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1; Short=hnRNP A1 [Caenorhabditis elegans]
# e.value: 4.75494e-70
# bit-score: 226.098
# hsp score: 575.0
# ****Alignment****
# sequence: sp|Q9CX86.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A0; Short=hnRNP A0 [Mus musculus]
# e.value: 1.5974e-69
# bit-score: 223.402
# hsp score: 568.0
# ****Alignment****
# sequence: sp|Q02926.1| RecName: Full=Ribonucleoprotein RB97D [Drosophila melanogaster]
# e.value: 1.35251e-55
# bit-score: 192.2
# hsp score: 487.0
# ****Alignment****
# sequence: sp|Q920Q6.1| RecName: Full=RNA-binding protein Musashi homolog 2; Short=Musashi-2 [Mus musculus]
# e.value: 5.1626e-47
# bit-score: 166.392
# hsp score: 420.0
# ****Alignment****
# sequence: sp|Q96DH6.1| RecName: Full=RNA-binding protein Musashi homolog 2; Short=Musashi-2 [Homo sapiens]
# e.value: 7.31254e-47
# bit-score: 165.236
# hsp score: 417.0
# ****Alignment****
# sequence: sp|O43347.1| RecName: Full=RNA-binding protein Musashi homolog 1; Short=Musashi-1 [Homo sapiens]
# e.value: 8.50021e-47
# bit-score: 166.007
# hsp score: 419.0
# ****Alignment****
# sequence: sp|Q61474.1| RecName: Full=RNA-binding protein Musashi homolog 1; Short=Musashi-1 [Mus musculus]
# e.value: 1.19064e-46
# bit-score: 165.622
# hsp score: 418.0
# ****Alignment****
# sequence: sp|Q8K3P4.1| RecName: Full=RNA-binding protein Musashi homolog 1; Short=Musashi-1 [Rattus norvegicus]
# e.value: 1.24186e-46
# bit-score: 165.622
# hsp score: 418.0
# ****Alignment****
# sequence: sp|Q9JJ54.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein D0; Short=hnRNP D0; AltName: Full=AU-rich element RNA-binding protein 1 [Rattus norvegicus]
# e.value: 2.43162e-46
# bit-score: 164.851
# hsp score: 416.0
# ****Alignment****
# sequence: sp|Q99020.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein A/B; Short=hnRNP A/B; AltName: Full=CArG-binding factor-A; Short=CBF-A [Mus musculus]
# e.value: 4.3762e-46
# bit-score: 162.155
# hsp score: 409.0
# ****Alignment****
# sequence: sp|Q14103.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D0; Short=hnRNP D0; AltName: Full=AU-rich element RNA-binding protein 1 [Homo sapiens]
# e.value: 4.74651e-46
# bit-score: 164.081
# hsp score: 414.0
# ****Alignment****
# sequence: sp|Q60668.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein D0; Short=hnRNP D0; AltName: Full=AU-rich element RNA-binding protein 1 [Mus musculus]
# e.value: 5.27352e-46
# bit-score: 164.081
# hsp score: 414.0
# ****Alignment****
# sequence: sp|Q9VVE5.3| RecName: Full=RNA-binding protein Musashi homolog Rbp6 [Drosophila melanogaster]
# e.value: 1.97366e-44
# bit-score: 160.229
# hsp score: 404.0
# ****Alignment****
# sequence: sp|O94432.1| RecName: Full=Uncharacterized RNA-binding protein C660.15 [Schizosaccharomyces pombe 972h-]
# e.value: 2.06667e-44
# bit-score: 162.54
# hsp score: 410.0
# ****Alignment****
# sequence: sp|Q99729.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A/B; Short=hnRNP A/B; AltName: Full=APOBEC1-binding protein 1; Short=ABBP-1 [Homo sapiens]
# e.value: 3.86399e-44
# bit-score: 158.303
# hsp score: 399.0
# ****Alignment****
# sequence: sp|Q3SWU3.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL [Rattus norvegicus]
# e.value: 2.64754e-41
# bit-score: 150.599
# hsp score: 379.0
# ****Alignment****
# sequence: sp|Q5ZI72.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL [Gallus gallus]
# e.value: 3.73043e-41
# bit-score: 149.443
# hsp score: 376.0
# ****Alignment****
# sequence: sp|Q9Z130.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL; AltName: Full=JKT41-binding protein [Mus musculus]
# e.value: 6.44457e-41
# bit-score: 149.058
# hsp score: 375.0
# ****Alignment****
# sequence: sp|Q8W034.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein 1; Short=hnRNP1 [Arabidopsis thaliana]
# e.value: 1.05038e-40
# bit-score: 151.369
# hsp score: 381.0
# ****Alignment****
# sequence: sp|O14979.3| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL; AltName: Full=AU-rich element RNA-binding factor; AltName: Full=JKT41-binding protein; AltName: Full=Protein laAUF1 [Homo sapiens]
# e.value: 5.57219e-40
# bit-score: 149.443
# hsp score: 376.0
# ****Alignment****
# sequence: sp|Q96EP5.1| RecName: Full=DAZ-associated protein 1; AltName: Full=Deleted in azoospermia-associated protein 1 [Homo sapiens]
# e.value: 2.1012e-39
# bit-score: 147.517
# hsp score: 371.0
# ****Alignment****
# sequence: sp|Q640A2.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like; Short=hnRNP D-like; Short=hnRNP DL [Xenopus tropicalis]
# e.value: 6.17873e-39
# bit-score: 143.665
# hsp score: 361.0
# ****Alignment****
# sequence: sp|P48809.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein 27C; Short=Hrb27-C; AltName: Full=HRP48.1; AltName: Full=hnRNP 48 [Drosophila melanogaster]
# e.value: 1.01722e-38
# bit-score: 145.976
# hsp score: 367.0
# ****Alignment****
# sequence: sp|Q9JII5.2| RecName: Full=DAZ-associated protein 1; AltName: Full=Deleted in azoospermia-associated protein 1 [Mus musculus]
# e.value: 1.10964e-38
# bit-score: 145.591
# hsp score: 366.0
# ****Alignment****
# sequence: sp|Q6NU14.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like-B; Short=hnRNP D-like B; Short=hnRNP DL-B [Xenopus laevis]
# e.value: 5.08294e-38
# bit-score: 140.969
# hsp score: 354.0
# ****Alignment****
# sequence: sp|Q98SJ2.1| RecName: Full=DAZ-associated protein 1; AltName: Full=Deleted in azoospermia-associated protein 1; AltName: Full=Proline-rich Vg1 mRNA-binding protein [Xenopus laevis]
# e.value: 9.62399e-38
# bit-score: 142.124
# hsp score: 357.0
# ****Alignment****
# sequence: sp|Q99383.1| RecName: Full=Nuclear polyadenylated RNA-binding protein 4; AltName: Full=Cleavage factor IB; Short=CFIB [Saccharomyces cerevisiae S288C]
# e.value: 1.96087e-37
# bit-score: 144.436
# hsp score: 363.0
# ****Alignment****
# sequence: sp|Q7ZX83.1| RecName: Full=Heterogeneous nuclear ribonucleoprotein D-like-A; Short=hnRNP D-like A; Short=hnRNP DL-A [Xenopus laevis]
# e.value: 4.41231e-37
# bit-score: 138.658
# hsp score: 348.0
# ****Alignment****
# sequence: sp|Q32P51.2| RecName: Full=Heterogeneous nuclear ribonucleoprotein A1-like 2; Short=hnRNP A1-like 2; AltName: Full=hnRNP core protein A1-like 2 [Homo sapiens]
# e.value: 1.30974e-25
# bit-score: 108.227
# hsp score: 269.0
# ****Alignment****
# sequence: sp|Q9C652.1| RecName: Full=RNA-binding protein 1; Short=AtRBP1 [Arabidopsis thaliana]
# e.value: 1.96001e-25
# bit-score: 108.612
# hsp score: 270.0
# [[<Bio.Blast.Record.HSP at 0x1c6ca9eddc0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57ca0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa578b0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa579a0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57d00>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57790>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa576a0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57040>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57cd0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57940>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57520>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57340>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57670>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa575b0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57ee0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57580>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa57fa0>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8b23a0>],
#  [<Bio.Blast.Record.HSP at 0x1c6c92eb2b0>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8a8250>],
#  [<Bio.Blast.Record.HSP at 0x1c6ca8a82b0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0ee20>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e7c0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0ea00>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e4c0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e5b0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e940>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e970>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e670>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0edf0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e820>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e580>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40940>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40d00>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40400>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa406d0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40a30>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa405b0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40c40>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40e20>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa409d0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0efa0>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa0e4f0>],
#  [<Bio.Blast.Record.HSP at 0x1c6c92ebb80>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40d60>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40b50>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40700>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40d90>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40070>],
#  [<Bio.Blast.Record.HSP at 0x1c6caa40130>]]

# %%
blast_result('NP_005893.1')
# Out:
# ****Alignment****
# sequence: sp|P84022.1| RecName: Full=Mothers against decapentaplegic homolog 3; Short=MAD homolog 3; Short=Mad3; Short=Mothers against DPP homolog 3; Short=hMAD-3; AltName: Full=JV15-2; AltName: Full=SMAD family member 3; Short=SMAD 3; Short=Smad3; Short=hSMAD3 [Homo sapiens] >sp|P84024.1| RecName: Full=Mothers against decapentaplegic homolog 3; Short=MAD homolog 3; Short=Mad3; Short=Mothers against DPP homolog 3; AltName: Full=SMAD family member 3; Short=SMAD 3; Short=Smad3 [Sus scrofa] >sp|P84025.1| RecName: Full=Mothers against decapentaplegic homolog 3; Short=MAD homolog 3; Short=Mad3; Short=Mothers against DPP homolog 3; AltName: Full=SMAD family member 3; Short=SMAD 3; Short=Smad3 [Rattus norvegicus] >sp|Q8BUN5.2| RecName: Full=Mothers against decapentaplegic homolog 3; Short=MAD homolog 3; Short=Mad3; Short=Mothers against DPP homolog 3; Short=mMad3; AltName: Full=SMAD family member 3; Short=SMAD 3; Short=Smad3 [Mus musculus]
# e.value: 0.0
# bit-score: 890.567
# hsp score: 2300.0
# ****Alignment****
# sequence: sp|P84023.1| RecName: Full=Mothers against decapentaplegic homolog 3; Short=MAD homolog 3; Short=Mad3; Short=Mothers against DPP homolog 3; AltName: Full=SMAD family member 3; Short=SMAD 3; Short=Smad3 [Gallus gallus]
# e.value: 0.0
# bit-score: 880.167
# hsp score: 2273.0
# ****Alignment****
# sequence: sp|Q62432.2| RecName: Full=Mothers against decapentaplegic homolog 2; Short=MAD homolog 2; Short=Mothers against DPP homolog 2; AltName: Full=Mad-related protein 2; Short=mMad2; AltName: Full=SMAD family member 2; Short=SMAD 2; Short=Smad2 [Mus musculus]
# e.value: 0.0
# bit-score: 779.245
# hsp score: 2011.0
# ****Alignment****
# sequence: sp|Q15796.1| RecName: Full=Mothers against decapentaplegic homolog 2; Short=MAD homolog 2; Short=Mothers against DPP homolog 2; AltName: Full=JV18-1; AltName: Full=Mad-related protein 2; Short=hMAD-2; AltName: Full=SMAD family member 2; Short=SMAD 2; Short=Smad2; Short=hSMAD2 [Homo sapiens]
# e.value: 0.0
# bit-score: 778.859
# hsp score: 2010.0
# ****Alignment****
# sequence: sp|Q5R7C0.1| RecName: Full=Mothers against decapentaplegic homolog 2; Short=MAD homolog 2; Short=Mothers against DPP homolog 2; AltName: Full=SMAD family member 2; Short=SMAD 2; Short=Smad2 [Pongo abelii]
# e.value: 0.0
# bit-score: 777.319
# hsp score: 2006.0
# ****Alignment****
# sequence: sp|O70436.1| RecName: Full=Mothers against decapentaplegic homolog 2; Short=MAD homolog 2; Short=Mothers against DPP homolog 2; AltName: Full=Mad-related protein 2; AltName: Full=SMAD family member 2; Short=SMAD 2; Short=Smad2 [Rattus norvegicus]
# e.value: 0.0
# bit-score: 777.319
# hsp score: 2006.0
# ****Alignment****
# sequence: sp|Q1W668.1| RecName: Full=Mothers against decapentaplegic homolog 2; Short=MAD homolog 2; Short=Mothers against DPP homolog 2; AltName: Full=SMAD family member 2; Short=SMAD 2; Short=Smad2 [Bos taurus]
# e.value: 0.0
# bit-score: 776.163
# hsp score: 2003.0
# ****Alignment****
# sequence: sp|Q9I9P9.1| RecName: Full=Mothers against decapentaplegic homolog 2; Short=MAD homolog 2; Short=Mothers against DPP homolog 2; AltName: Full=SMAD family member 2; Short=SMAD 2; Short=Smad2 [Danio rerio]
# e.value: 0.0
# bit-score: 754.977
# hsp score: 1948.0
# ****Alignment****
# sequence: sp|P97454.2| RecName: Full=Mothers against decapentaplegic homolog 5; Short=MAD homolog 5; Short=Mothers against DPP homolog 5; AltName: Full=Dwarfin-C; Short=Dwf-C; AltName: Full=SMAD family member 5; Short=SMAD 5; Short=Smad5; Short=mSmad5 [Mus musculus]
# e.value: 0.0
# bit-score: 546.199
# hsp score: 1406.0
# ****Alignment****
# sequence: sp|Q56I99.1| RecName: Full=Mothers against decapentaplegic homolog 5; Short=MAD homolog 5; Short=Mothers against DPP homolog 5; AltName: Full=SMAD family member 5; Short=SMAD 5; Short=Smad5 [Gallus gallus]
# e.value: 0.0
# bit-score: 545.814
# hsp score: 1405.0
# ****Alignment****
# sequence: sp|Q5R6H7.1| RecName: Full=Mothers against decapentaplegic homolog 5; Short=MAD homolog 5; Short=Mothers against DPP homolog 5; AltName: Full=SMAD family member 5; Short=SMAD 5; Short=Smad5 [Pongo abelii] >sp|Q99717.1| RecName: Full=Mothers against decapentaplegic homolog 5; Short=MAD homolog 5; Short=Mothers against DPP homolog 5; AltName: Full=JV5-1; AltName: Full=SMAD family member 5; Short=SMAD 5; Short=Smad5; Short=hSmad5 [Homo sapiens]
# e.value: 0.0
# bit-score: 544.658
# hsp score: 1402.0
# ****Alignment****
# sequence: sp|Q9W7E7.1| RecName: Full=Mothers against decapentaplegic homolog 5; Short=MAD homolog 5; Short=Mothers against DPP homolog 5; AltName: Full=Protein somitabun; AltName: Full=SMAD family member 5; Short=SMAD 5; Short=Smad5 [Danio rerio]
# e.value: 0.0
# bit-score: 542.732
# hsp score: 1397.0
# ****Alignment****
# sequence: sp|Q9R1V3.1| RecName: Full=Mothers against decapentaplegic homolog 5; Short=MAD homolog 5; Short=Mothers against DPP homolog 5; AltName: Full=SMAD family member 5; Short=SMAD 5; Short=Smad5 [Rattus norvegicus]
# e.value: 0.0
# bit-score: 542.347
# hsp score: 1396.0
# ****Alignment****
# sequence: sp|P42003.1| RecName: Full=Protein mothers against dpp [Drosophila melanogaster]
# e.value: 0.0
# bit-score: 539.65
# hsp score: 1389.0
# ****Alignment****
# sequence: sp|Q15797.1| RecName: Full=Mothers against decapentaplegic homolog 1; Short=MAD homolog 1; Short=Mothers against DPP homolog 1; AltName: Full=JV4-1; AltName: Full=Mad-related protein 1; AltName: Full=SMAD family member 1; Short=SMAD 1; Short=Smad1; Short=hSMAD1; AltName: Full=Transforming growth factor-beta-signaling protein 1; Short=BSP-1 [Homo sapiens]
# e.value: 0.0
# bit-score: 536.954
# hsp score: 1382.0
# ****Alignment****
# sequence: sp|Q9I962.1| RecName: Full=Mothers against decapentaplegic homolog 1; Short=MAD homolog 1; Short=Mothers against DPP homolog 1; AltName: Full=Mad-related protein 1; AltName: Full=SMAD family member 1; Short=SMAD 1; Short=Smad1 [Coturnix japonica]
# e.value: 0.0
# bit-score: 536.569
# hsp score: 1381.0
# ****Alignment****
# sequence: sp|Q1JQA2.1| RecName: Full=Mothers against decapentaplegic homolog 1; Short=MAD homolog 1; Short=Mothers against DPP homolog 1; AltName: Full=SMAD family member 1; Short=SMAD 1; Short=Smad1 [Bos taurus]
# e.value: 0.0
# bit-score: 536.569
# hsp score: 1381.0
# ****Alignment****
# sequence: sp|P97588.1| RecName: Full=Mothers against decapentaplegic homolog 1; Short=MAD homolog 1; Short=Mothers against DPP homolog 1; AltName: Full=SMAD family member 1; Short=SMAD 1; Short=Smad1 [Rattus norvegicus]
# e.value: 0.0
# bit-score: 534.258
# hsp score: 1375.0
# ****Alignment****
# sequence: sp|Q9JIW5.2| RecName: Full=Mothers against decapentaplegic homolog 9; Short=MAD homolog 9; Short=Mothers against DPP homolog 9; AltName: Full=SMAD family member 9; Short=SMAD 9; Short=Smad9; AltName: Full=Smad8 [Mus musculus]
# e.value: 0.0
# bit-score: 533.872
# hsp score: 1374.0
# ****Alignment****
# sequence: sp|P70340.2| RecName: Full=Mothers against decapentaplegic homolog 1; Short=MAD homolog 1; Short=Mothers against DPP homolog 1; AltName: Full=Dwarfin-A; Short=Dwf-A; AltName: Full=Mothers-against-DPP-related 1; Short=Mad-related protein 1; Short=mMad1; AltName: Full=SMAD family member 1; Short=SMAD 1; Short=Smad1 [Mus musculus]
# e.value: 0.0
# bit-score: 533.102
# hsp score: 1372.0
# ****Alignment****
# sequence: sp|O15198.1| RecName: Full=Mothers against decapentaplegic homolog 9; Short=MAD homolog 9; Short=Mothers against DPP homolog 9; AltName: Full=Madh6; AltName: Full=SMAD family member 9; Short=SMAD 9; Short=Smad9 [Homo sapiens]
# e.value: 0.0
# bit-score: 529.635
# hsp score: 1363.0
# ****Alignment****
# sequence: sp|Q9I8V2.1| RecName: Full=Mothers against decapentaplegic homolog 1; Short=MAD homolog 1; Short=Mothers against DPP homolog 1; AltName: Full=SMAD family member 1; Short=SMAD 1; Short=Smad1 [Danio rerio]
# e.value: 0.0
# bit-score: 525.783
# hsp score: 1353.0
# ****Alignment****
# sequence: sp|O54835.1| RecName: Full=Mothers against decapentaplegic homolog 9; Short=MAD homolog 9; Short=Mothers against DPP homolog 9; AltName: Full=SMAD family member 9; Short=SMAD 9; Short=Smad9; AltName: Full=Smad8 [Rattus norvegicus]
# e.value: 1.48172e-180
# bit-score: 513.072
# hsp score: 1320.0
# ****Alignment****
# sequence: sp|Q02330.2| RecName: Full=Dwarfin sma-2; AltName: Full=MAD protein homolog 1 [Caenorhabditis elegans]
# e.value: 4.13121e-129
# bit-score: 381.719
# hsp score: 979.0
# ****Alignment****
# sequence: sp|P45896.1| RecName: Full=Dwarfin sma-3; AltName: Full=MAD protein homolog 2 [Caenorhabditis elegans]
# e.value: 9.05435e-96
# bit-score: 295.819
# hsp score: 756.0
# ****Alignment****
# sequence: sp|P45897.1| RecName: Full=Dwarfin sma-4; AltName: Full=MAD protein homolog 3 [Caenorhabditis elegans]
# e.value: 6.36227e-57
# bit-score: 199.519
# hsp score: 506.0
# ****Alignment****
# sequence: sp|P97471.2| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=Deletion target in pancreatic carcinoma 4 homolog; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4 [Mus musculus]
# e.value: 1.05237e-47
# bit-score: 174.481
# hsp score: 441.0
# ****Alignment****
# sequence: sp|P97471.2| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=Deletion target in pancreatic carcinoma 4 homolog; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4 [Mus musculus]
# e.value: 2.03082e-29
# bit-score: 123.635
# hsp score: 309.0
# ****Alignment****
# sequence: sp|Q13485.1| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=Deletion target in pancreatic carcinoma 4; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4; Short=hSMAD4 [Homo sapiens]
# e.value: 1.39447e-47
# bit-score: 174.096
# hsp score: 440.0
# ****Alignment****
# sequence: sp|Q13485.1| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=Deletion target in pancreatic carcinoma 4; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4; Short=hSMAD4 [Homo sapiens]
# e.value: 1.97557e-30
# bit-score: 126.331
# hsp score: 316.0
# ****Alignment****
# sequence: sp|O70437.1| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4 [Rattus norvegicus]
# e.value: 1.42326e-47
# bit-score: 174.096
# hsp score: 440.0
# ****Alignment****
# sequence: sp|O70437.1| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4 [Rattus norvegicus]
# e.value: 2.63795e-30
# bit-score: 125.946
# hsp score: 315.0
# ****Alignment****
# sequence: sp|Q9GKQ9.1| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4 [Sus scrofa]
# e.value: 1.43788e-47
# bit-score: 174.096
# hsp score: 440.0
# ****Alignment****
# sequence: sp|Q9GKQ9.1| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4 [Sus scrofa]
# e.value: 3.45462e-30
# bit-score: 125.561
# hsp score: 314.0
# ****Alignment****
# sequence: sp|Q1HE26.1| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4 [Bos taurus]
# e.value: 1.53714e-47
# bit-score: 174.096
# hsp score: 440.0
# ****Alignment****
# sequence: sp|Q1HE26.1| RecName: Full=Mothers against decapentaplegic homolog 4; Short=MAD homolog 4; Short=Mothers against DPP homolog 4; AltName: Full=SMAD family member 4; Short=SMAD 4; Short=Smad4 [Bos taurus]
# e.value: 6.02225e-30
# bit-score: 125.176
# hsp score: 313.0
# ****Alignment****
# sequence: sp|O43541.2| RecName: Full=Mothers against decapentaplegic homolog 6; Short=MAD homolog 6; Short=Mothers against DPP homolog 6; AltName: Full=SMAD family member 6; Short=SMAD 6; Short=Smad6; Short=hSMAD6 [Homo sapiens]
# e.value: 4.85253e-37
# bit-score: 144.436
# hsp score: 363.0
# ****Alignment****
# sequence: sp|O35182.1| RecName: Full=Mothers against decapentaplegic homolog 6; Short=MAD homolog 6; Short=Mothers against DPP homolog 6; AltName: Full=Mad homolog 7; AltName: Full=SMAD family member 6; Short=SMAD 6; Short=Smad6 [Mus musculus]
# e.value: 5.56339e-37
# bit-score: 144.05
# hsp score: 362.0
# ****Alignment****
# sequence: sp|Q9W734.1| RecName: Full=Mothers against decapentaplegic homolog 6; Short=MAD homolog 6; Short=Mothers against DPP homolog 6; AltName: Full=SMAD family member 6; Short=SMAD 6; Short=Smad6 [Gallus gallus]
# e.value: 5.63464e-33
# bit-score: 131.724
# hsp score: 330.0
# ****Alignment****
# sequence: sp|O88406.2| RecName: Full=Mothers against decapentaplegic homolog 7; Short=MAD homolog 7; Short=Mothers against DPP homolog 7; AltName: Full=SMAD family member 7; Short=SMAD 7; Short=Smad7 [Rattus norvegicus]
# e.value: 4.50406e-27
# bit-score: 115.161
# hsp score: 287.0
# ****Alignment****
# sequence: sp|O15105.1| RecName: Full=Mothers against decapentaplegic homolog 7; Short=MAD homolog 7; Short=Mothers against DPP homolog 7; AltName: Full=Mothers against decapentaplegic homolog 8; Short=MAD homolog 8; Short=Mothers against DPP homolog 8; AltName: Full=SMAD family member 7; Short=SMAD 7; Short=Smad7; Short=hSMAD7 [Homo sapiens]
# e.value: 4.77578e-27
# bit-score: 115.161
# hsp score: 287.0
# ****Alignment****
# sequence: sp|O35253.1| RecName: Full=Mothers against decapentaplegic homolog 7; Short=MAD homolog 7; Short=Mothers against DPP homolog 7; AltName: Full=Mothers against decapentaplegic homolog 8; Short=MAD homolog 8; Short=Mothers against DPP homolog 8; AltName: Full=SMAD family member 7; Short=SMAD 7; Short=Smad7 [Mus musculus]
# e.value: 8.57549e-27
# bit-score: 114.39
# hsp score: 285.0
# [[<Bio.Blast.Record.HSP at 0x1c6cc318a60>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc31dc40>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc327400>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc327970>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32a190>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32a310>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32a460>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32a400>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32a4f0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32aa30>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32ac10>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32abe0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32acd0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32af40>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc32afd0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc330fa0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc330040>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc330400>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc3307f0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc330910>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc3308e0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc330d90>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc3340a0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334100>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334730>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334850>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc3347f0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334880>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334970>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc3347c0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334ac0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334910>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334c40>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334a90>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc336610>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc334be0>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc336670>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc336790>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc336970>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc336a60>],
#  [<Bio.Blast.Record.HSP at 0x1c6cc336a00>],
#  [<Bio.Blast.Record.HSP at 0x1c6cb92efd0>]]

# %% [markdown]
# A lista de listas 'a' vai ter os objectos Blast Record HSP resultantes da pesquisa anterior

# %%
for i in a:
    print(type(i))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# ### As sequências que resultaram em E-values baixos, bit-scores elevados e scores elevados têm uma elevada probabilidade de serem sequências homólogas.
# Assim, o resultado da função **blast_result** corresponde à lista de sequências homólogas.
